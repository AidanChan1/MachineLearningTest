# %%
import numpy


a = np.arange(8)
print (a)
a.reshape(2,4)

# %%
import numpy

# %%
import matplotlib

# %%
import numpy as np
print("hehehaha")

# %% [markdown]
# # lamda function, set seed random

# %%
random.uniform(0, 0.1)

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

def scrambler(slope, intercept): 
    x = np.arange(5,10,0.05)
    y_pred = x.copy()
    # below can be replaced by a lambda function
    for i in range(len(y_pred)):
        y_pred[i] = slope*y_pred[i]+random.uniform(0, 2)+intercept
    return x, y_pred

def least_square(slope,intercept,dataset_x, dataset_y_pred):
    lsr = pow(slope*dataset_x + intercept - dataset_y_pred, 2)
    return np.mean(lsr)
    #a = [0]*len(dataset1)
    #for i in range(len(dataset1)):
    #    a[i] = pow(slope*dataset1[i]+intercept-dataset2[i],2)
    #return sum(a)/len(dataset1)
    #A = a*b
    #B = [number ** 2 for number in a]
    #m = (sum(A)-sum(a)*sum(b))/(sum(b)-pow(sum(a),2))
    #z = (sum(b)-m*sum(a))/len(a)
    #return m, zz8
    #A = np.vstack([a, np.ones(len(a))]).T
    #return np.linalg.lstsq(A, b,rcond=None)[0]
    
x,y_pred = scrambler(random.uniform(3, 8) ,random.uniform(10, 15))


slope = np.arange(3,8,0.1)
intercept = np.arange(10,15,0.5)
lsr_list = []
for s in slope:
    for i in intercept:
        lsr = least_square(s, i, x, y_pred)
        lsr_list.append(lsr)
#print (lsr_array)
lsr_array = np.array(lsr_list)
lsr_array.reshape(slope.size, intercept.size)

test = np.reshape(lsr_array, (-1, 2))

#print (test.ndim)
#print (test)
#g = np.zeros((len(sl),len(inter)))



#for i in range(len(sl)):
#    for j in range(len(inter)):
#        g[i][j] = ls(sl[i],inter[j],c, d)
#        if(g[i][j]<0.5):
#            print(sl[i],inter[j],g[i][j])



#plt.hist2d(x, y, bins=(300, 300), cmap=plt.cm.jet)
#plt.show()
#print(g[aaaaa][bbbbb], aaaaa, bbbbb)
#plt.plot(c,d)
# Out:
# 2
# [[6.27105186e+01 5.50765284e+01]
#  [4.79425382e+01 4.13085480e+01]
#  [3.51745578e+01 2.95405677e+01]
#  [2.44065775e+01 1.97725873e+01]
#  [1.56385971e+01 1.20046069e+01]
#  [5.13680599e+01 4.44815697e+01]
#  [3.80950795e+01 3.22085893e+01]
#  [2.68220991e+01 2.19356089e+01]
#  [1.75491187e+01 1.36626285e+01]
#  [1.02761383e+01 7.38964812e+00]
#  [4.11847761e+01 3.50457859e+01]
#  [2.94067957e+01 2.42678055e+01]
#  [1.96288153e+01 1.54898251e+01]
#  [1.18508349e+01 8.71184475e+00]
#  [6.07285456e+00 3.93386436e+00]
#  [3.21606673e+01 2.67691771e+01]
#  [2.18776870e+01 1.74861968e+01]
#  [1.35947066e+01 1.02032164e+01]
#  [7.31172618e+00 4.92023599e+00]
#  [3.02874580e+00 1.63725561e+00]
#  [2.42957336e+01 1.96517434e+01]
#  [1.55077532e+01 1.18637630e+01]
#  [8.71977281e+00 6.07578262e+00]
#  [3.93179243e+00 2.28780223e+00]
#  [1.14381204e+00 4.99821848e-01]
#  [1.75899748e+01 1.36934846e+01]
#  [1.02969944e+01 7.40050425e+00]
#  [5.00401405e+00 3.10752386e+00]
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import numpy as np

# Load and format data

#print (sl)
#print (inter)
slope, intercept = np.meshgrid(slope, intercept)
#print (type(g))

#region = np.s_[5:50, 5:50]
#sl, inter, g = sl[region], inter[region], g[region]
fig, ax = plt.subplots(subplot_kw=dict(projection='3d'))
# ls = LightSource(270, 45)
# To use a custom hillshading mode, override the built-in shading and pass
# in the rgb colors of the shaded surface calculated from "shade".
# rgb = ls.shade(g, cmap=cm.gist_earth, vert_exag=0.001, blend_mode='soft')
surf = ax.plot_surface(slope, intercept, test, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False, shade=False)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [6], in <cell line: 20>()
#      15 fig, ax = plt.subplots(subplot_kw=dict(projection='3d'))
#      16 # ls = LightSource(270, 45)
#      17 # To use a custom hillshading mode, override the built-in shading and pass
#      18 # in the rgb colors of the shaded surface calculated from "shade".
#      19 # rgb = ls.shade(g, cmap=cm.gist_earth, vert_exag=0.001, blend_mode='soft')
# ---> 20 surf = ax.plot_surface(slope, intercept, test, cmap=cm.coolwarm,
#      21                        linewidth=0, antialiased=False, shade=False)
#      23 plt.show()
#
# File /opt/homebrew/lib/python3.9/site-packages/matplotlib/_api/deprecation.py:415, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     405     deprecation_addendum = (
#     406         f"If any parameter follows {name!r}, they should be passed as "
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import numpy as np

fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

# Make data.
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# Customize the z axis.
ax.set_zlim(-1.01, 1.01)
ax.zaxis.set_major_locator(LinearLocator(10))
# A StrMethodFormatter is used automatically
ax.zaxis.set_major_formatter('{x:.02f}')

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %%
from matplotlib import cbook
from matplotlib import cm
from matplotlib.colors import LightSource
import matplotlib.pyplot as plt
import numpy as np

# Load and format data
dem = cbook.get_sample_data('jacksboro_fault_dem.npz', np_load=True)
z = dem['elevation']
nrows, ncols = z.shape
x = np.linspace(dem['xmin'], dem['xmax'], ncols)
y = np.linspace(dem['ymin'], dem['ymax'], nrows)
x, y = np.meshgrid(x, y)

region = np.s_[5:50, 5:50]
x, y, z = x[region], y[region], z[region]

# Set up plotu 
fig, ax = plt.subplots(subplot_kw=dict(projection='3d'))
  
print (type(z))

ls = LightSource(270, 45)
# To use a custom hillshading mode, override the built-in shading and pass
# in the rgb colors of the shaded surface calculated from "shade".
rgb = ls.shade(z, cmap=cm.gist_earth, vert_exag=0.1, blend_mode='soft') 
surf = ax.plot_surface(x, y, z, rstride=1, cstride=1, facecolors=rgb,
                       linewidth=0, antialiased=False, shade=False)

plt.show()
# Out:
# <class 'numpy.ndarray'>
